# %%
import numpy as np 
import pandas as pd

# %%
ds=pd.read_csv('BX-Books.csv',sep=";",error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3300\3806731281.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ds=pd.read_csv('BX-Books.csv',sep=";",error_bad_lines=False,encoding='latin-1')
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...

# %%
ds
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ds.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
ds.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
ds=ds[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher']]

# %%
ds.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year'},inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3300\600599294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year'},inplace=True)

# %%
ds.head(5)
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   Publisher
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company

# %%
users=pd.read_csv("BX-Users.csv",sep=";",error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3300\3449109785.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   users=pd.read_csv("BX-Users.csv",sep=";",error_bad_lines=False,encoding='latin-1')

# %%
users.head(3)
# Out:
#    User-ID                         Location   Age
# 0        1               nyc, new york, usa   NaN
# 1        2        stockton, california, usa  18.0
# 2        3  moscow, yukon territory, russia   NaN

# %%
users.rename(columns={'User-ID':'user_id'})
# Out:
#         user_id                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
rating=pd.read_csv("BX-Book-Ratings.csv",sep=";",error_bad_lines=False,encoding='latin-1')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3300\3491009461.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   rating=pd.read_csv("BX-Book-Ratings.csv",sep=";",error_bad_lines=False,encoding='latin-1')

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
rating.rename(columns={'User-ID':'user_id','Book-Rating':'Brating'},inplace=True)

# %%
rating.head()
# Out:
#    user_id        ISBN  Brating
# 0   276725  034545104X        0
# 1   276726  0155061224        5
# 2   276727  0446520802        0
# 3   276729  052165615X        3
# 4   276729  0521795028        6

# %%
ds.shape
# Out:
# (271360, 5)

# %%
users.shape
# Out:
# (278858, 3)

# %%
rating.shape
# Out:
# (1149780, 3)

# %%
rating.head(2)
# Out:
#    user_id        ISBN  Brating
# 0   276725  034545104X        0
# 1   276726  0155061224        5

# %%
x=rating['user_id'].value_counts() > 200
x[x]
# Out:
# 11676     True
# 198711    True
# 153662    True
# 98391     True
# 35859     True
#           ...
# 274808    True
# 28634     True
# 59727     True
# 268622    True
# 188951    True
# Name: user_id, Length: 899, dtype: bool

# %%
y=x[x].index

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727,
#             268622, 188951],
#            dtype='int64', length=899)

# %%
rating=rating[rating['user_id'].isin(y)]

# %%
rating.shape
# Out:
# (526356, 3)

# %%
rating.head()
# Out:
#       user_id        ISBN  Brating
# 1456   277427  002542730X       10
# 1457   277427  0026217457        0
# 1458   277427  003008685X        8
# 1459   277427  0030615321        0
# 1460   277427  0060002050        0

# %%
ratings_with_books=rating.merge(ds,on='ISBN')

# %%
ratings_with_books.shape
# Out:
# (487671, 7)

# %%
num_rating=ratings_with_books.groupby('title')['Brating'].count().reset_index()

# %%
num_rating
# Out:
#                                                     title  Brating
# 0        A Light in the Storm: The Civil War Diary of ...        2
# 1                                   Always Have Popsicles        1
# 2                    Apple Magic (The Collector's series)        1
# 3        Beyond IBM: Leadership Marketing and Finance ...        1
# 4        Clifford Visita El Hospital (Clifford El Gran...        1
# ...                                                   ...      ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...        3
# 160265                                      Ã?Â?lpiraten.        1
# 160266                     Ã?Â?rger mit Produkt X. Roman.        1
# 160267                              Ã?Â?stlich der Berge.        1
# 160268                                  Ã?Â?thique en toc        1
#
# [160269 rows x 2 columns]

# %%
num_rating.rename(columns={'Brating':'number of ratings'},inplace=True)

# %%
finalrating=ratings_with_books.merge(num_rating,on='title')

# %%
finalrating
# Out:
#         user_id        ISBN  Brating  \
# 0        277427  002542730X       10
# 1          3363  002542730X        0
# 2         11676  002542730X        6
# 3         12538  002542730X       10
# 4         13552  002542730X        0
# ...         ...         ...      ...
# 487666   275970  1892145022        0
# 487667   275970  1931868123        0
# 487668   275970  3411086211       10
# 487669   275970  3829021860        0
# 487670   275970  4770019572        0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 487666                                   Here Is New York
# ...

# %%
finalrating.shape
# Out:
# (487671, 8)

# %%
finalrating=finalrating[finalrating['number of ratings']>=50]

# %%
finalrating.shape
# Out:
# (61853, 8)

# %%
finalrating.drop_duplicates(['user_id','title'],inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3300\3719444966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalrating.drop_duplicates(['user_id','title'],inplace=True)

# %%
finalrating.shape
# Out:
# (59850, 8)

# %%
book_pivot=finalrating.pivot_table(columns='user_id',index='title',values='Brating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
book_sparse=csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors as nn

# %%
model=nn(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances, suggestions=model.kneighbors(book_pivot.iloc[241,:].values.reshape(1,-1))

# %%
distances
# Out:
# array([[ 0.        , 56.69215113, 57.94825278, 58.88972746, 59.05082557]])

# %%
suggestions
# Out:
# array([[241, 291, 184, 485, 688]], dtype=int64)

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Harry Potter and the Sorcerer's Stone (Book 1)', 'Jacob Have I Loved',
#        'Exclusive', 'Table For Two', 'Tough Cookie'],
#       dtype='object', name='title')

# %%
book_pivot.index[240]
# Out:
# 'Harry Potter and the Prisoner of Azkaban (Book 3)'

# %%
np.where(book_pivot.index=='Animal Farm')[0][0]
# Out:
# 54

# %%
def recommendation(book_name):
    book_id=np.where(book_pivot.index==book_name)[0][0]
    distances, suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1))
    
    for i in range(len(suggestions)):
        if i==0:
            print("The suggestions for",book_name,"are : ")
        if not i:
            print(book_pivot.index[suggestions[i]])

# %%
recommendation("Harry Potter and the Sorcerer's Stone (Book 1)")
# Out:
# The suggestions for Harry Potter and the Sorcerer's Stone (Book 1) are :
# Index(['Harry Potter and the Sorcerer's Stone (Book 1)', 'Jacob Have I Loved',
#        'Exclusive', 'Table For Two', 'Tough Cookie'],
#       dtype='object', name='title')
